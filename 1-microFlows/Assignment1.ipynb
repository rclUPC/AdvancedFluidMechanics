# %% [markdown]
# # Assignment 1. Computation of journal bearing

# %% [markdown]
# It is possible to use the Reynolds equation to compute de eccentricity and the angle of a journal bearing with fluid film lubrication, given the load $W$
#
# ![image.png](https://github.com/Biel-PS/AdvancedFluidMechanics/blob/BielPS/1-microFlows/Journal_bearing1.png?raw=1)
#
# Consider that the journal is displaced in the $x$ negative direction, so that $h(\theta) = h_0(1+\varepsilon \cos(\theta))$ where $\varepsilon=\frac{e}{h_0}$ is the relative eccentricity and $h_0 = \frac{1}{2}(D_b -D_a)$ is the average gap thickness. The journal is rotating in the positive direction of $\theta$ (polar coordinates)
#
# ![image.png](https://github.com/Biel-PS/AdvancedFluidMechanics/blob/BielPS/1-microFlows/Journal_bearing2.png?raw=1)
#
# 1. Calculate the pressure distribution $p(\theta)$ and the value and direction of $\mathbf{W}$, in the approximation $\varepsilon \ll 1$.
# 2. What happens to the journal if $\mathbf{W}$ increase a little bit?
# 3. Apply the results to this real [example](https://www.mcmaster.com/6658K738/), and discuss the value of the maximum load given by the manufactures at this rotational velocity.
# ![image.png](https://github.com/Biel-PS/AdvancedFluidMechanics/blob/BielPS/1-microFlows/McMaster-Carr_JB.png?raw=1)

# %%
import sympy as sp
sp.init_printing()

x,y,t,mu = sp.symbols('x,y,t,mu')
u = sp.Function('u')
p = sp.Function('p')
h = sp.Function('h')
p_x = sp.Function('p_x') # This function is the gradient of pressure in x direction

exp = -p_x(x)/mu+sp.diff(u(y),y,2)
sp.Eq(exp,0)

Ub,Ut = sp.symbols('U_b,U_t')
ics = {u(0):Ub,u(h(x)):Ut}

Sol = sp.dsolve(exp,u(y),ics=ics)
Sol = Sol.simplify()

U = sp.symbols('U')
Sol = Sol.replace(Ut,U).replace(Ub,0)

intU = sp.integrate(Sol.rhs,(y,0,h(x)))

ReynoldsEq = sp.Eq(intU.diff(x),0)
ReynoldsEq = ReynoldsEq.expand()

q = sp.symbols('q')
exp_dpdx = sp.solve(intU-q,p_x(x))

p_eq = sp.Eq(p_x(x), exp_dpdx[0])
p_eq = p_eq.replace(p_x(x),p(x).diff(x))

h0,epsi,r = sp.symbols('h_0, epsilon,r')
p_eq = p_eq.replace(h(x),h0*(1+epsi*sp.cos(x))) #theta for x
display(p_eq)



pref = sp.symbols('p_ref')
p_sol = sp.dsolve(p_eq,p(x),ics={p(0):pref,p(2*sp.pi):pref})
display(p_sol)
# Out:
# d          6⋅μ⋅(U⋅h₀⋅(ε⋅cos(x) + 1) - 2⋅q)
# ──(p(x)) = ───────────────────────────────
# dx                 3               3
#                  h₀ ⋅(ε⋅cos(x) + 1)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-d9ebad6bd7df> in <cell line: 0>()
#      36
#      37 pref = sp.symbols('p_ref')
# ---> 38 p_sol = sp.dsolve(p_eq,p(x),ics={p(0):pref,p(2*sp.pi):pref})
#      39 display(p_sol)
#
# /usr/local/lib/python3.11/dist-packages/sympy/solvers/ode/ode.py in dsolve(eq, func, hint, simplify, ics, xi, eta, x0, n, **kwargs)
#     638             # The key 'hint' stores the hint needed to be solved for.
#     639             hint = hints['hint']
# --> 640             return _helper_simplify(eq, hint, hints, simplify, ics=ics)
#     641
#     642
#
# /usr/local/lib/python3.11/dist-packages/sympy/solvers/ode/ode.py in _helper_simplify(eq, hint, match, simplify, ics, **kwargs)
#     668         # simplifications
#     669         if isinstance(solvefunc, SingleODESolver):
# --> 670             sols = solvefunc.get_general_solution()
#     671         else:
#     672             sols = solvefunc(eq, func, order, match)
#
# /usr/local/lib/python3.11/dist-packages/sympy/solvers/ode/single.py in get_general_solution(self, simplify)
#     281             msg = "%s solver cannot solve:\n%s"
#     282             raise ODEMatchError(msg % (self.hint, self.ode_problem.eq))
# --> 283         return self._get_general_solution(simplify_flag=simplify)
#     284
#     285     def _matches(self) -> bool:
#
# /usr/local/lib/python3.11/dist-packages/sympy/solvers/ode/single.py in _get_general_solution(self, simplify_flag)
#     895         for eq in eqns:
#     896             try:
# --> 897                 sol = dsolve(eq, func(x))
#     898             except NotImplementedError:
#     899                 continue
#
# /usr/local/lib/python3.11/dist-packages/sympy/solvers/ode/ode.py in dsolve(eq, func, hint, simplify, ics, xi, eta, x0, n, **kwargs)
#     638             # The key 'hint' stores the hint needed to be solved for.
#     639             hint = hints['hint']
# --> 640             return _helper_simplify(eq, hint, hints, simplify, ics=ics)
#     641
#     642
#
# /usr/local/lib/python3.11/dist-packages/sympy/solvers/ode/ode.py in _helper_simplify(eq, hint, match, simplify, ics, **kwargs)
#     674             rv = []
#     675             for s in sols:
# --> 676                 simp = odesimp(eq, s, func, hint)
#     677                 if iterable(simp):
#     678                     rv.extend(simp)
#
# /usr/local/lib/python3.11/dist-packages/sympy/core/multidimensional.py in wrapper(*args, **kwargs)
#     128                     result = apply_on_element(wrapper, args, kwargs, n)
#     129                     return result
# --> 130             return f(*args, **kwargs)
#     131         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sympy/solvers/ode/ode.py in odesimp(ode, eq, func, hint)
#    1634
#    1635     # First, integrate if the hint allows it.
# -> 1636     eq = _handle_Integral(eq, func, hint)
#    1637     if hint.startswith("nth_linear_euler_eq_nonhomogeneous"):
#    1638         eq = simplify(eq)
#
# /usr/local/lib/python3.11/dist-packages/sympy/solvers/ode/ode.py in _handle_Integral(expr, func, hint)
#    2188         sol = expr
#    2189     elif not hint.endswith("_Integral"):
# -> 2190         sol = expr.doit()
#    2191     else:
#    2192         sol = expr
#
# /usr/local/lib/python3.11/dist-packages/sympy/core/basic.py in doit(self, **hints)
#    1925         """
#    1926         if hints.get('deep', True):
# -> 1927             terms = [term.doit(**hints) if isinstance(term, Basic) else term
#    1928                                          for term in self.args]
#    1929             return self.func(*terms)
#
# /usr/local/lib/python3.11/dist-packages/sympy/core/basic.py in <listcomp>(.0)
#    1925         """
#    1926         if hints.get('deep', True):
# -> 1927             terms = [term.doit(**hints) if isinstance(term, Basic) else term
#    1928                                          for term in self.args]
#    1929             return self.func(*terms)
#
# /usr/local/lib/python3.11/dist-packages/sympy/core/operations.py in doit(self, **hints)
#     453     def doit(self, **hints):
#     454         if hints.get('deep', True):
# --> 455             terms = [term.doit(**hints) for term in self.args]
#     456         else:
#     457             terms = self.args
#
# /usr/local/lib/python3.11/dist-packages/sympy/core/operations.py in <listcomp>(.0)
#     453     def doit(self, **hints):
#     454         if hints.get('deep', True):
# --> 455             terms = [term.doit(**hints) for term in self.args]
#     456         else:
#     457             terms = self.args
#
# /usr/local/lib/python3.11/dist-packages/sympy/integrals/integrals.py in doit(self, **hints)
#     617                     antideriv = None
#     618                 else:
# --> 619                     antideriv = self._eval_integral(
#     620                         function, xab[0], **eval_kwargs)
#     621                     if antideriv is None and meijerg is True:
#
# /usr/local/lib/python3.11/dist-packages/sympy/integrals/integrals.py in _eval_integral(self, f, x, meijerg, risch, manual, heurisch, conds, final)
#    1089                     try:
#    1090                         if conds == 'piecewise':
# -> 1091                             h = heurisch_wrapper(g, x, hints=[])
#    1092                         else:
#    1093                             h = heurisch_(g, x, hints=[])
#
# /usr/local/lib/python3.11/dist-packages/sympy/integrals/heurisch.py in heurisch_wrapper(f, x, rewrite, hints, mappings, retries, degree_offset, unnecessary_permutations, _try_heurisch)
#     142         return f*x
#     143
# --> 144     res = heurisch(f, x, rewrite, hints, mappings, retries, degree_offset,
#     145                    unnecessary_permutations, _try_heurisch)
#     146     if not isinstance(res, Basic):
#
# /usr/local/lib/python3.11/dist-packages/sympy/integrals/heurisch.py in heurisch(f, x, rewrite, hints, mappings, retries, degree_offset, unnecessary_permutations, _try_heurisch)
#     773     else:
#     774         if retries >= 0:
# --> 775             result = heurisch(f, x, mappings=mappings, rewrite=rewrite, hints=hints, retries=retries - 1, unnecessary_permutations=unnecessary_permutations)
#     776
#     777             if result is not None:
#
# /usr/local/lib/python3.11/dist-packages/sympy/integrals/heurisch.py in heurisch(f, x, rewrite, hints, mappings, retries, degree_offset, unnecessary_permutations, _try_heurisch)
#     531     else:
#     532         if not rewrite:
# --> 533             result = heurisch(f, x, rewrite=True, hints=hints,
#     534                 unnecessary_permutations=unnecessary_permutations)
#     535
#
# /usr/local/lib/python3.11/dist-packages/sympy/integrals/heurisch.py in heurisch(f, x, rewrite, hints, mappings, retries, degree_offset, unnecessary_permutations, _try_heurisch)
#     761             solution = _integrate()
#     762     else:
# --> 763         solution = _integrate()
#     764
#     765     if solution is not None:
#
# /usr/local/lib/python3.11/dist-packages/sympy/integrals/heurisch.py in _integrate(field)
#     737         ring = PolyRing(V, coeff_ring)
#     738         try:
# --> 739             numer = ring.from_expr(raw_numer)
#     740         except ValueError:
#     741             raise PolynomialError
#
# /usr/local/lib/python3.11/dist-packages/sympy/polys/rings.py in from_expr(self, expr)
#     395
#     396         try:
# --> 397             poly = self._rebuild_expr(expr, mapping)
#     398         except CoercionFailed:
#     399             raise ValueError("expected an expression convertible to a polynomial in %s, got %s" % (self, expr))
#
# /usr/local/lib/python3.11/dist-packages/sympy/polys/rings.py in _rebuild_expr(self, expr, mapping)
#     389                     return self.ground_new(domain.convert(expr))
#     390
# --> 391         return _rebuild(sympify(expr))
#     392
#     393     def from_expr(self, expr):
#
# /usr/local/lib/python3.11/dist-packages/sympy/polys/rings.py in _rebuild(expr)
#     377                 return generator
#     378             elif expr.is_Add:
# --> 379                 return reduce(add, list(map(_rebuild, expr.args)))
#     380             elif expr.is_Mul:
#     381                 return reduce(mul, list(map(_rebuild, expr.args)))
#
# /usr/local/lib/python3.11/dist-packages/sympy/polys/rings.py in _rebuild(expr)
#     379                 return reduce(add, list(map(_rebuild, expr.args)))
#     380             elif expr.is_Mul:
# --> 381                 return reduce(mul, list(map(_rebuild, expr.args)))
#     382             else:
#     383                 # XXX: Use as_base_exp() to handle Pow(x, n) and also exp(n)
#
# /usr/local/lib/python3.11/dist-packages/sympy/polys/rings.py in __mul__(p1, p2)
#    1116                 for exp2, v2 in p2it:
#    1117                     exp = monomial_mul(exp1, exp2)
# -> 1118                     p[exp] = get(exp, zero) + v1*v2
#    1119             p.strip_zero()
#    1120             return p
#
# /usr/local/lib/python3.11/dist-packages/sympy/polys/rings.py in __mul__(p1, p2)
#    1116                 for exp2, v2 in p2it:
#    1117                     exp = monomial_mul(exp1, exp2)
# -> 1118                     p[exp] = get(exp, zero) + v1*v2
#    1119             p.strip_zero()
#    1120             return p
#
# /usr/local/lib/python3.11/dist-packages/sympy/polys/domains/expressiondomain.py in __mul__(f, g)
#     110                 return f.__class__(f.ex*g.ex)
#     111
# --> 112             return f.simplify(f.ex*g.ex)
#     113
#     114         def __rmul__(f, g):
#
# /usr/local/lib/python3.11/dist-packages/sympy/polys/domains/expressiondomain.py in simplify(f, ex)
#      52
#      53         def simplify(f, ex):
# ---> 54             return f.__class__(ex.cancel().expand(**eflags))
#      55
#      56         def __abs__(f):
#
# /usr/local/lib/python3.11/dist-packages/sympy/core/expr.py in cancel(self, *gens, **args)
#    3780         """See the cancel function in sympy.polys"""
#    3781         from sympy.polys.polytools import cancel
# -> 3782         return cancel(self, *gens, **args)
#    3783
#    3784     def invert(self, g, *gens, **args):
#
# /usr/local/lib/python3.11/dist-packages/sympy/polys/polytools.py in cancel(f, _signsimp, *gens, **args)
#    7162             return f
#    7163         f = factor_terms(f, radical=True)
# -> 7164         p, q = f.as_numer_denom()
#    7165
#    7166     elif len(f) == 2:
#
# /usr/local/lib/python3.11/dist-packages/sympy/core/mul.py in as_numer_denom(self)
#    1233         # as the order is not guaranteed to be the same once they have
#    1234         # been separated from each other
# -> 1235         numers, denoms = list(zip(*[f.as_numer_denom() for f in self.args]))
#    1236         return self.func(*numers), self.func(*denoms)
#    1237
#
# /usr/local/lib/python3.11/dist-packages/sympy/core/mul.py in <listcomp>(.0)
#    1233         # as the order is not guaranteed to be the same once they have
#    1234         # been separated from each other
# -> 1235         numers, denoms = list(zip(*[f.as_numer_denom() for f in self.args]))
#    1236         return self.func(*numers), self.func(*denoms)
#    1237
#
# /usr/local/lib/python3.11/dist-packages/sympy/core/add.py in as_numer_denom(self)
#     584         """
#     585         # clear rational denominator
# --> 586         content, expr = self.primitive()
#     587         if not isinstance(expr, Add):
#     588             return Mul(content, expr, evaluate=False).as_numer_denom()
#
# /usr/local/lib/python3.11/dist-packages/sympy/core/add.py in primitive(self)
#    1144         if not inf:
#    1145             ngcd = reduce(igcd, [t[0] for t in terms], 0)
# -> 1146             dlcm = reduce(ilcm, [t[1] for t in terms], 1)
#    1147         else:
#    1148             ngcd = reduce(igcd, [t[0] for t in terms if t[1]], 0)
#
# /usr/local/lib/python3.11/dist-packages/sympy/core/intfunc.py in ilcm(*args)
#     340
#     341
# --> 342 def ilcm(*args):
#     343     """Computes integer least common multiple.
#     344
#
# KeyboardInterrupt:
